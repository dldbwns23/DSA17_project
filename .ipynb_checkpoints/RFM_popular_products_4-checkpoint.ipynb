# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
import plotly.express as px
mpl.rc('font', family='Malgun Gothic')

df_member = pd.read_csv('Member_Data.csv', encoding='EUC-KR')
df_product = pd.read_csv('Product_Data.csv')
df_sales = pd.read_csv('Sales_Data05.csv')

# %%
# 날짜 변환
df_sales['주문일시'] = pd.to_datetime(df_sales['주문일시'], errors='coerce')
latest_date = df_sales['주문일시'].max()  # 데이터 내 최신 주문일

# RFM분석
rfm = pd.pivot_table(df_sales, index="회원번호",values=["주문일시", "구매금액"],
    aggfunc={"주문일시": [lambda x: (latest_date - x.max()).days, "count"], "구매금액": "sum"}).reset_index()

# 컬럼 이름 변경
rfm.columns = ["회원번호", "Recency", "Frequency", "Monetary"]

# RFM 점수 (5단계 )
rfm["R_Score"] = pd.qcut(rfm["Recency"], 5, labels=[5, 4, 3, 2, 1])
rfm["F_Score"] = pd.qcut(rfm["Frequency"], 5, labels=[1, 2, 3, 4, 5])
rfm["M_Score"] = pd.qcut(rfm["Monetary"], 5, labels=[1, 2, 3, 4, 5])

# 최종 RFM 점수 계산
rfm["RFM_Score"] = rfm[["R_Score", "F_Score", "M_Score"]].astype(int).sum(axis=1)

# %%
# RFM 분석에 사용할 데이터만 뽑기
RFM = rfm[['회원번호', 'R_Score', 'F_Score', 'M_Score', 'RFM_Score']]
coustomer_and_product_num = df_sales[['회원번호', '제품번호']]
product_type = df_product[['제품번호', '물품대분류', '물품중분류']]

# 병합
df_merged = RFM.merge(coustomer_and_product_num, on='회원번호', how='inner')
df_merged_RFM = df_merged.merge(product_type, on='제품번호', how='inner')
df_merged_RFM.head(5)
# Out:
#        회원번호 R_Score F_Score M_Score  RFM_Score              제품번호 물품대분류  물품중분류
# 0  18764160       2       3       4          9    10002574V2_441    음료     빙과
# 1  18764160       2       3       4          9  100022290V2_1708    음료     빙과
# 2  18764160       2       3       4          9  100022169V2_1631     빵  앙금크림빵
# 3  18764160       2       3       4          9  100021606V2_1200    음료     빙과
# 4  18764160       2       3       4          9    10002805V2_612  생활용품  치약/칫솔

# %% [markdown]
# # 2. 고객 RFM 점수에 따른 물품대분류 별 인기상품 트렌드 분석

# %% [markdown]
# - RFM_Score(총합) 기준

# %%
# EDA
rfm['RFM_Score'].value_counts()
# Out:
# RFM_Score
# 8     2528
# 7     2513
# 9     2445
# 10    2347
# 11    2203
# 12     301
# 6      193
# 5        7
# 13       3
# Name: count, dtype: int64

# %%
RFM_Score_list = [5, 6, 7, 8, 9, 10, 11, 12, 13]

for score in RFM_Score_list :
    RFM_cond = df_merged_RFM['RFM_Score'] == score
    df_RFM_Score = df_merged_RFM.loc[RFM_cond]

    # RFM_Score 점수 별 인기상품 시각화 (X - 물품대분류 / Y - 판매개수)
    sns.displot(data = df_RFM_Score, x = '물품대분류', height=10, aspect=4)
    plt.xlabel('물품대분류')
    plt.ylabel('빈도수')
    plt.title(f'RFM {score}점 고객 인기상품 분포')

    # 그래프 이미지파일로 저장
    plt.savefig(f'RFM_{score}score_popular_products_image.png')

# %% [markdown]
# # 고객 RFM점수 별 물품 판매 개수 출력

# %%
# 각 고객 RFM점수에 해당하는 물품대분류 별 상품 판매 수
for score in RFM_Score_list :
    RFM_cond = df_merged_RFM['RFM_Score'] == score
    df_RFM_Score = df_merged_RFM.loc[RFM_cond]

    print(f"<< RFM {score}점 물품대분류 별 상품 판매 갯수 >>")
    print(df_RFM_Score['물품대분류'].value_counts())
    print("\n\n")
# Out:
# << RFM 5점 물품대분류 별 상품 판매 갯수 >>
# 물품대분류
# 건강일반      10
# 중량(정육)     5
# 육가공        3
# 보리/혼합곡     2
# 소금         1
# 수산가공       1
# 냉동수산       1
# 열매채소       1
# 두부/유부      1
# 닭/오리       1
# 어묵/묵       1
# 가루         1
# 과일         1
# 해조         1
# Name: count, dtype: int64
#
#
#
# << RFM 6점 물품대분류 별 상품 판매 갯수 >>
# 물품대분류
# 두부/유부       368
# 알           328
# 음료          278
# 과자          223
# 밀가공         217
# 잎/줄기채소      210
# 육가공         200
# 중량(정육)      182
# 유제품         172
# 열매채소        170
# 소           166
# 냉동수산        155
# 과일          152
# 양념채소        152
# 빵           150
# 떡           139
# 밑반찬         139
# 건강일반        138
# 가루          138
# 건어물         136
# 뿌리채소        132
# 해조          130
# 화장품         125
# 수산가공        122
# 돼지          115
# 멥쌀          114
# 콩나물         114
# 닭/오리        113
# 식사대용        112
# 생활용품         96
# 기름/식초        90
# 과일채소         89
# 장            81
# 소스/기타양념      80
# 세제/세안        76
# 버섯           70
# 콩/화본/깨       69
# 어묵/묵         69
# 쌈채소류         63
# 잼/병조림/기타     61
# 차            55
# 즉석조리         47
# 절임/장아찌       45
# 말린나물/건재      42
# 견과           39
# 꿀            38
# 생물수산         33
# 홍삼/녹용        32
# 찹쌀           27
# 김치           26
# 보리/혼합곡       19
# 소금           18
# 식기/편백        13
# 전통주           8
# 손질한채소         6
# 유색미/발아미       6
# 섬유            2
# Name: count, dtype: int64
#
#
#
# << RFM 7점 물품대분류 별 상품 판매 갯수 >>
# 물품대분류
# 잎/줄기채소      24909
# 두부/유부       24037
# 알           21640
# 열매채소        17068
# 과자          16364
# 양념채소        14204
# 음료          14040
# 유제품         13978
# 빵           12556
# 밀가공         12519
# 과일          11223
# 육가공         10154
# 뿌리채소         9860
# 콩나물          9186
# 떡            8885
# 과일채소         8793
# 버섯           8263
# 밑반찬          7760
# 중량(정육)       6846
# 냉동수산         6839
# 쌈채소류         6176
# 돼지           6164
# 가루           5888
# 소            5813
# 해조           5746
# 식사대용         5708
# 어묵/묵         5351
# 건어물          5322
# 멥쌀           5151
# 세제/세안        4958
# 닭/오리         4863
# 생활용품         4373
# 소스/기타양념      4162
# 수산가공         4012
# 기름/식초        3884
# 화장품          3786
# 콩/화본/깨       3363
# 장            3031
# 건강일반         2985
# 생물수산         2964
# 절임/장아찌       2643
# 즉석조리         2264
# 말린나물/건재      2048
# 차            1960
# 견과           1815
# 잼/병조림/기타     1805
# 찹쌀           1264
# 김치           1208
# 보리/혼합곡       1007
# 소금            664
# 꿀             641
# 식기/편백         548
# 전통주           544
# 홍삼/녹용         538
# 유색미/발아미       522
# 손질한채소         392
# 섬유            139
# 과실주            76
# 김장채소            1
# Name: count, dtype: int64
#
#
#
# << RFM 8점 물품대분류 별 상품 판매 갯수 >>
# 물품대분류
# 두부/유부       12461
# 알           10055
# 잎/줄기채소       9329
# 과자           7149
# 음료           6834
# 열매채소         6155
# 양념채소         5898
# 밀가공          5509
# 유제품          5399
# 빵            4806
# 육가공          4783
# 콩나물          4377
# 뿌리채소         4239
# 과일           3675
# 버섯           3561
# 밑반찬          3428
# 떡            3388
# 해조           3013
# 가루           3005
# 냉동수산         2995
# 식사대용         2821
# 쌈채소류         2686
# 과일채소         2584
# 돼지           2516
# 어묵/묵         2473
# 건어물          2413
# 중량(정육)       2385
# 소            2312
# 세제/세안        2224
# 멥쌀           2101
# 닭/오리         2075
# 생활용품         2009
# 수산가공         1859
# 소스/기타양념      1818
# 기름/식초        1729
# 화장품          1575
# 콩/화본/깨       1429
# 절임/장아찌       1383
# 건강일반         1376
# 장            1331
# 잼/병조림/기타     1028
# 차            1005
# 즉석조리          951
# 말린나물/건재       931
# 생물수산          894
# 견과            697
# 찹쌀            518
# 보리/혼합곡        483
# 김치            472
# 소금            349
# 유색미/발아미       288
# 홍삼/녹용         269
# 꿀             260
# 전통주           239
# 식기/편백         194
# 손질한채소         167
# 과실주            35
# 섬유             31
# Name: count, dtype: int64
#
#
#
# << RFM 9점 물품대분류 별 상품 판매 갯수 >>
# 물품대분류
# 두부/유부       6184
# 알           4369
# 잎/줄기채소      4102
# 과자          3750
# 음료          3635
# 밀가공         2754
# 양념채소        2577
# 열매채소        2521
# 빵           2241
# 육가공         2183
# 콩나물         2162
# 유제품         2025
# 뿌리채소        1924
# 떡           1789
# 밑반찬         1557
# 가루          1545
# 냉동수산        1526
# 식사대용        1407
# 해조          1405
# 버섯          1368
# 과일          1352
# 건어물         1212
# 쌈채소류        1198
# 과일채소        1144
# 어묵/묵        1127
# 돼지          1112
# 세제/세안       1085
# 생활용품         969
# 소            940
# 수산가공         918
# 멥쌀           911
# 중량(정육)       887
# 닭/오리         869
# 소스/기타양념      856
# 기름/식초        835
# 콩/화본/깨       787
# 화장품          703
# 건강일반         685
# 장            677
# 절임/장아찌       560
# 차            552
# 즉석조리         540
# 말린나물/건재      511
# 잼/병조림/기타     457
# 생물수산         456
# 견과           379
# 보리/혼합곡       238
# 찹쌀           235
# 김치           189
# 소금           186
# 홍삼/녹용        124
# 꿀            120
# 유색미/발아미      119
# 식기/편백        116
# 전통주           96
# 손질한채소         77
# 섬유            12
# 과실주           12
# Name: count, dtype: int64
#
#
#
# << RFM 10점 물품대분류 별 상품 판매 갯수 >>
# 물품대분류
# 두부/유부       2789
# 과자          2299
# 음료          1982
# 알           1949
# 잎/줄기채소      1774
# 밀가공         1292
# 빵           1180
# 양념채소        1118
# 육가공         1117
# 유제품         1106
# 열매채소        1000
# 콩나물          951
# 뿌리채소         891
# 밑반찬          812
# 가루           796
# 식사대용         761
# 떡            760
# 해조           701
# 과일           647
# 과일채소         610
# 버섯           602
# 냉동수산         591
# 세제/세안        548
# 어묵/묵         536
# 생활용품         512
# 건어물          511
# 돼지           494
# 소            494
# 쌈채소류         488
# 수산가공         477
# 소스/기타양념      464
# 닭/오리         461
# 멥쌀           445
# 중량(정육)       425
# 화장품          412
# 기름/식초        412
# 콩/화본/깨       371
# 건강일반         360
# 차            309
# 장            307
# 절임/장아찌       295
# 잼/병조림/기타     266
# 말린나물/건재      232
# 즉석조리         227
# 생물수산         198
# 견과           195
# 찹쌀           127
# 김치           109
# 보리/혼합곡       106
# 소금            77
# 유색미/발아미       61
# 꿀             58
# 식기/편백         54
# 전통주           50
# 손질한채소         41
# 홍삼/녹용         37
# 과실주            7
# 섬유             2
# Name: count, dtype: int64
#
#
#
# << RFM 11점 물품대분류 별 상품 판매 갯수 >>
# 물품대분류
# 두부/유부       1194
# 과자          1160
# 잎/줄기채소       949
# 음료           914
# 알            812
# 밀가공          647
# 양념채소         547
# 유제품          516
# 빵            515
# 콩나물          474
# 뿌리채소         450
# 해조           445
# 육가공          416
# 가루           395
# 떡            354
# 밑반찬          338
# 식사대용         335
# 과일           325
# 버섯           325
# 열매채소         307
# 생활용품         269
# 세제/세안        267
# 냉동수산         263
# 어묵/묵         245
# 수산가공         245
# 쌈채소류         245
# 과일채소         239
# 건어물          224
# 기름/식초        196
# 돼지           189
# 중량(정육)       189
# 닭/오리         180
# 차            179
# 장            172
# 소            162
# 소스/기타양념      161
# 콩/화본/깨       158
# 화장품          158
# 건강일반         139
# 멥쌀           136
# 잼/병조림/기타     124
# 절임/장아찌       112
# 즉석조리         111
# 생물수산         100
# 말린나물/건재       93
# 견과            91
# 소금            69
# 찹쌀            53
# 김치            48
# 보리/혼합곡        38
# 유색미/발아미       34
# 손질한채소         24
# 식기/편백         22
# 전통주           20
# 꿀             16
# 홍삼/녹용         15
# 섬유             5
# 과실주            1
# Name: count, dtype: int64
#
#
#
# << RFM 12점 물품대분류 별 상품 판매 갯수 >>
# 물품대분류
# 과자          231
# 두부/유부       221
# 잎/줄기채소      158
# 음료          152
# 알           142
# 빵           129
# 밀가공         101
# 양념채소         85
# 콩나물          82
# 뿌리채소         78
# 유제품          78
# 식사대용         69
# 버섯           69
# 떡            62
# 밑반찬          49
# 육가공          46
# 해조           44
# 수산가공         40
# 어묵/묵         38
# 쌈채소류         37
# 가루           37
# 소스/기타양념      31
# 냉동수산         29
# 열매채소         29
# 과일           25
# 건어물          24
# 차            23
# 세제/세안        22
# 절임/장아찌       22
# 즉석조리         20
# 생활용품         20
# 과일채소         18
# 돼지           18
# 콩/화본/깨       18
# 닭/오리         17
# 잼/병조림/기타     17
# 말린나물/건재      17
# 장            16
# 생물수산         16
# 건강일반         14
# 소             9
# 기름/식초         9
# 화장품           9
# 소금            7
# 중량(정육)        7
# 멥쌀            6
# 찹쌀            5
# 견과            5
# 김치            4
# 보리/혼합곡        4
# 전통주           2
# 꿀             1
# 손질한채소         1
# Name: count, dtype: int64
#
#
#
# << RFM 13점 물품대분류 별 상품 판매 갯수 >>
# 물품대분류
# 음료        5
# 빵         4
# 과자        3
# 두부/유부     3
# 버섯        3
# 떡         2
# 양념채소      2
# 콩나물       2
# 육가공       1
# 잎/줄기채소    1
# 유제품       1
# 뿌리채소      1
# 열매채소      1
# 기름/식초     1
# Name: count, dtype: int64

# %%
# RFM점수에 해당하는 물품중분류 별 상품 판매 수
for score in RFM_Score_list :
    RFM_cond = df_merged_RFM['RFM_Score'] == score
    df_RFM_Score = df_merged_RFM.loc[RFM_cond]

    print(f"<< RFM {score}점 물품중분류 별 상품 판매 갯수 >>")
    print(df_RFM_Score['물품중분류'].value_counts())
    print("\n\n")
# Out:
# << RFM 5점 물품중분류 별 상품 판매 갯수 >>
# 물품중분류
# 추출/농축액    10
# 돼지(중량)     5
# 식육추출가공     3
# 보리         2
# 가공소금       1
# 젓갈/액젓      1
# 기타냉동수산     1
# 찰옥수수       1
# 콩가공/기타     1
# 무항생제닭      1
# 묵          1
# 고춧가루       1
# 귤(조생)      1
# 미역/다시마     1
# Name: count, dtype: int64
#
#
#
# << RFM 6점 물품중분류 별 상품 판매 갯수 >>
# 물품중분류
# 두부         330
# 논지엠오유정란    252
# 스낵         157
# 추출/농축액     130
# 멥쌀         114
#           ...
# 베타쌈배추        1
# 레몬           1
# 비타민고추        1
# 씀바귀          1
# 돌나물          1
# Name: count, Length: 295, dtype: int64
#
#
#
# << RFM 7점 물품중분류 별 상품 판매 갯수 >>
# 물품중분류
# 두부         21415
# 논지엠오유정란    16431
# 스낵         12926
# 우유/산양유      8805
# 콩나물         7415
#            ...
# 개복숭아           2
# 청갓             1
# 오가피순           1
# 가루/기타          1
# 즙용브로컬리         1
# Name: count, Length: 380, dtype: int64
#
#
#
# << RFM 8점 물품중분류 별 상품 판매 갯수 >>
# 물품중분류
# 두부         11318
# 논지엠오유정란     7357
# 스낵          5564
# 콩나물         3655
# 우유/산양유      3479
#            ...
# 울금             1
# 아동             1
# 영지버섯           1
# 마              1
# 떡케이크/선물        1
# Name: count, Length: 371, dtype: int64
#
#
#
# << RFM 9점 물품중분류 별 상품 판매 갯수 >>
# 물품중분류
# 두부             5553
# 논지엠오유정란        3162
# 스낵             2903
# 콩나물            1823
# 과즙             1292
#                ...
# 알로에               1
# 갓끈동부              1
# 울금                1
# 삼채잎               1
# 토란줄기말림(70g)       1
# Name: count, Length: 361, dtype: int64
#
#
#
# << RFM 10점 물품중분류 별 상품 판매 갯수 >>
# 물품중분류
# 두부               2446
# 스낵               1817
# 논지엠오유정란          1364
# 과즙                872
# 콩나물               809
#                  ...
# 말린곤드레나물(100g)       1
# 울금                  1
# 홍화나물                1
# 고구마순말림(70g)         1
# 상황버섯                1
# Name: count, Length: 346, dtype: int64
#
#
#
# << RFM 11점 물품중분류 별 상품 판매 갯수 >>
# 물품중분류
# 두부         1105
# 스낵          913
# 논지엠오유정란     546
# 콩나물         401
# 과즙          389
#            ...
# 연근말림          1
# 보리순           1
# 고구마순          1
# 생강            1
# 케일            1
# Name: count, Length: 321, dtype: int64
#
#
#
# << RFM 12점 물품중분류 별 상품 판매 갯수 >>
# 물품중분류
# 두부         201
# 스낵         188
# 논지엠오유정란     96
# 콩나물         73
# 과즙          68
#           ...
# 재래종중파        1
# 호두           1
# 장아찌          1
# 연근           1
# 아욱           1
# Name: count, Length: 229, dtype: int64
#
#
#
# << RFM 13점 물품중분류 별 상품 판매 갯수 >>
# 물품중분류
# 과즙          4
# 앙금크림빵       3
# 두부          3
# 스낵          3
# 즉석떡         2
# 콩나물         2
# 팽이버섯        2
# 햄/소시지/훈제    1
# 오이          1
# 페스츄리류       1
# 기름          1
# 빙과          1
# 청경채         1
# 당근          1
# 우유/산양유      1
# 양파          1
# 쪽파          1
# 느타리버섯       1
# Name: count, dtype: int64
